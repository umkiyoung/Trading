# %% [markdown]
# # Generalization with OOP: The MeanRevBacktester Class

# %% [markdown]
# ## Using the MeanRevBacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
plt.style.use("seaborn")

# %%
df = pd.read_csv("intraday_pairs.csv", parse_dates = ["time"], index_col = "time")
df
# Out:
#                              EURUSD    GBPUSD    EURAUD
# time
# 2018-01-01 22:00:00+00:00  1.201205  1.351705  1.533390
# 2018-01-02 04:00:00+00:00  1.207055  1.354830  1.540480
# 2018-01-02 10:00:00+00:00  1.204440  1.357860  1.537980
# 2018-01-02 16:00:00+00:00  1.205800  1.359180  1.540185
# 2018-01-02 22:00:00+00:00  1.204690  1.359530  1.542225
# ...                             ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  1.311810  1.602420
# 2019-12-30 04:00:00+00:00  1.119940  1.311880  1.600800
# 2019-12-30 10:00:00+00:00  1.120095  1.311465  1.601165
# 2019-12-30 16:00:00+00:00  1.119920  1.310990  1.601135
# 2019-12-30 22:00:00+00:00  1.120355  1.312675  1.599830
#
# [2075 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2075 entries, 2018-01-01 22:00:00+00:00 to 2019-12-30 22:00:00+00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  2070 non-null   float64
#  1   GBPUSD  2074 non-null   float64
#  2   EURAUD  2071 non-null   float64
# dtypes: float64(3)
# memory usage: 64.8 KB

# %%
ptc = 0.00007

# %%
import MeanRevBacktester as MeanRev

# %%
tester = MeanRev.MeanRevBacktester("EURUSD", 30, 2, "2018-01-01", "2019-12-31", ptc)

# %%
tester
# Out:
# MeanRevBacktester(symbol = EURUSD, SMA = 30, dev = 2, start = 2018-01-01, end = 2019-12-31)

# %%
tester.test_strategy()
# Out:
# (1.069792, 0.132076)

# %%
tester.results
# Out:
#                               price   returns       SMA     Lower     Upper  \
# time
# 2018-01-11 10:00:00+00:00  1.204915  0.008455  1.200628  1.190841  1.210415
# 2018-01-11 16:00:00+00:00  1.203205 -0.001420  1.200500  1.190964  1.210035
# 2018-01-11 22:00:00+00:00  1.205165  0.001628  1.200524  1.190943  1.210104
# 2018-01-12 04:00:00+00:00  1.212530  0.006093  1.200748  1.190374  1.211122
# 2018-01-12 10:00:00+00:00  1.214820  0.001887  1.201086  1.189583  1.212589
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092  1.111391  1.105215  1.117567
# 2019-12-30 04:00:00+00:00  1.119940  0.000018  1.111553  1.104754  1.118352
# 2019-12-30 10:00:00+00:00  1.120095  0.000138  1.111777  1.104318  1.119235
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156  1.111996  1.103981  1.120011
# 2019-12-30 22:00:00+00:00  1.120355  0.000388  1.112256  1.103679  1.120832
#
#                            distance  position  strategy  trades  creturns  \
# time
# 2018-01-11 10:00:00+00:00  0.004287       0.0  0.000000     0.0  1.008491
# 2018-01-11 16:00:00+00:00  0.002705       0.0 -0.000000     0.0  1.007060
# 2018-01-11 22:00:00+00:00  0.004641       0.0  0.000000     0.0  1.008700
# 2018-01-12 04:00:00+00:00  0.011782      -1.0 -0.000070     1.0  1.014865
# 2018-01-12 10:00:00+00:00  0.013734      -1.0 -0.001887     0.0  1.016781
# ...                             ...       ...       ...     ...       ...
# 2019-12-29 22:00:00+00:00  0.008529      -1.0 -0.002092     0.0  0.937352
# 2019-12-30 04:00:00+00:00  0.008387      -1.0 -0.000018     0.0  0.937369
# 2019-12-30 10:00:00+00:00  0.008318      -1.0 -0.000138     0.0  0.937498
# 2019-12-30 16:00:00+00:00  0.007924      -1.0  0.000156     0.0  0.937352
# 2019-12-30 22:00:00+00:00  0.008099      -1.0 -0.000388     0.0  0.937716
#
#                            cstrategy
# time
# 2018-01-11 10:00:00+00:00   1.000000
# 2018-01-11 16:00:00+00:00   1.000000
# 2018-01-11 22:00:00+00:00   1.000000
# 2018-01-12 04:00:00+00:00   0.999930
# 2018-01-12 10:00:00+00:00   0.998045
# ...                              ...
# 2019-12-29 22:00:00+00:00   1.070207
# 2019-12-30 04:00:00+00:00   1.070188
# 2019-12-30 10:00:00+00:00   1.070040
# 2019-12-30 16:00:00+00:00   1.070207
# 2019-12-30 22:00:00+00:00   1.069792
#
# [2040 rows x 11 columns]

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 100, 1), (1, 5, 1))
# Out:
# ((58, 1), 1.238111)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                               price   returns       SMA     Lower     Upper  \
# time
# 2018-01-22 10:00:00+00:00  1.225370  0.000343  1.210748  1.198848  1.222648
# 2018-01-22 16:00:00+00:00  1.226135  0.000624  1.211077  1.199018  1.223136
# 2018-01-22 22:00:00+00:00  1.225780 -0.000290  1.211445  1.199267  1.223623
# 2018-01-23 04:00:00+00:00  1.223765 -0.001645  1.211755  1.199495  1.224015
# 2018-01-23 10:00:00+00:00  1.229295  0.004509  1.212179  1.199743  1.224614
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092  1.111350  1.107982  1.114718
# 2019-12-30 04:00:00+00:00  1.119940  0.000018  1.111591  1.108116  1.115065
# 2019-12-30 10:00:00+00:00  1.120095  0.000138  1.111843  1.108291  1.115395
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156  1.112074  1.108438  1.115709
# 2019-12-30 22:00:00+00:00  1.120355  0.000388  1.112306  1.108578  1.116033
#
#                            distance  position  strategy  trades  creturns  \
# time
# 2018-01-22 10:00:00+00:00  0.014622      -1.0 -0.000343     0.0  1.000343
# 2018-01-22 16:00:00+00:00  0.015058      -1.0 -0.000624     0.0  1.000967
# 2018-01-22 22:00:00+00:00  0.014335      -1.0  0.000290     0.0  1.000678
# 2018-01-23 04:00:00+00:00  0.012010      -1.0  0.001645     0.0  0.999033
# 2018-01-23 10:00:00+00:00  0.017116      -1.0 -0.004509     0.0  1.003547
# ...                             ...       ...       ...     ...       ...
# 2019-12-29 22:00:00+00:00  0.008570      -1.0 -0.002092     0.0  0.914258
# 2019-12-30 04:00:00+00:00  0.008349      -1.0 -0.000018     0.0  0.914274
# 2019-12-30 10:00:00+00:00  0.008252      -1.0 -0.000138     0.0  0.914401
# 2019-12-30 16:00:00+00:00  0.007846      -1.0  0.000156     0.0  0.914258
# 2019-12-30 22:00:00+00:00  0.008049      -1.0 -0.000388     0.0  0.914613
#
#                            cstrategy
# time
# 2018-01-22 10:00:00+00:00   0.999657
# 2018-01-22 16:00:00+00:00   0.999034
# 2018-01-22 22:00:00+00:00   0.999323
# 2018-01-23 04:00:00+00:00   1.000968
# 2018-01-23 10:00:00+00:00   0.996465
# ...                              ...
# 2019-12-29 22:00:00+00:00   1.238592
# 2019-12-30 04:00:00+00:00   1.238569
# 2019-12-30 10:00:00+00:00   1.238398
# 2019-12-30 16:00:00+00:00   1.238592
# 2019-12-30 22:00:00+00:00   1.238111
#
# [2012 rows x 11 columns]

# %%
tester.results_overview
# Out:
#      SMA  dev  performance
# 0     25    1     0.995746
# 1     25    2     1.050603
# 2     25    3     1.039728
# 3     25    4     1.000000
# 4     26    1     0.995291
# ..   ...  ...          ...
# 295   98    4     1.000000
# 296   99    1     1.166676
# 297   99    2     1.168985
# 298   99    3     1.018584
# 299   99    4     1.000000
#
# [300 rows x 3 columns]

# %%
tester.results_overview.nlargest(10, "performance")
# Out:
#      SMA  dev  performance
# 132   58    1     1.238111
# 136   59    1     1.231034
# 148   62    1     1.230248
# 152   63    1     1.229423
# 128   57    1     1.228237
# 144   61    1     1.225364
# 116   54    1     1.223270
# 156   64    1     1.223054
# 140   60    1     1.222840
# 172   68    1     1.217669

# %%
tester.results_overview.nsmallest(10, "performance")
# Out:
#     SMA  dev  performance
# 4    26    1     0.995291
# 0    25    1     0.995746
# 30   32    3     0.999410
# 3    25    4     1.000000
# 7    26    4     1.000000
# 11   27    4     1.000000
# 15   28    4     1.000000
# 19   29    4     1.000000
# 23   30    4     1.000000
# 27   31    4     1.000000

# %% [markdown]
# __Backtesting & Forward Testing__

# %%
train = MeanRev.MeanRevBacktester("EURUSD", 30, 2, "2018-01-01", "2018-12-31", ptc)

# %%
train.optimize_parameters((25, 100, 1), (1, 5, 1)) # in-sample
# Out:
# ((74, 1), 1.151185)

# %%
train.plot_results() # in-sample

# %%
tester = MeanRev.MeanRevBacktester("EURUSD", 74, 1, "2019-01-01", "2019-12-31", ptc) # out-sample

# %%
tester.test_strategy()
# Out:
# (1.040341, 0.058301)

# %%
tester.plot_results()

# %% [markdown]
# __GBP/USD__

# %%
tester = MeanRev.MeanRevBacktester("GBPUSD", 30, 2, "2018-01-01", "2019-12-31", 0)

# %%
tester.test_strategy()
# Out:
# (1.004615, 0.031372)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 100, 1), (1, 5, 1))
# Out:
# ((79, 1), 1.178929)

# %%
tester.plot_results()
