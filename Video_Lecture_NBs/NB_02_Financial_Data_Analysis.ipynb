# %% [markdown]
# # Financial Data Analysis

# %% [markdown]
# ## Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT" ]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-02-06")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777554  27.933918  80.328041  18.936365  23.623899
# 2010-01-05  6.516527  45.211357  27.864241  79.357674  18.707300  23.631529
# 2010-01-06  6.412873  46.582802  27.716162  78.842171  18.700668  23.486509
# 2010-01-07  6.401017  48.468552  27.724874  78.569275  18.654179  23.242250
# 2010-01-08  6.443574  48.001011  27.768425  79.357674  18.308918  23.402550
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL          BA         DIS         IBM         KO
# Date
# 2023-01-30  142.781998  209.669998  107.589996  133.658249  60.178402
# 2023-01-31  144.070023  213.000000  108.489998  133.095169  60.853226
# 2023-02-01  145.208282  214.750000  109.389999  133.450790  60.863152
# 2023-02-02  150.590088  209.339996  113.209999  134.735031  59.821140
# 2023-02-03  154.264465  206.009995  110.709999  135.278351  59.374569
#
#                              Close                                      ...  \
#                   MSFT        AAPL          BA         DIS         IBM  ...
# Date                                                                    ...
# 2023-01-30  242.103607  143.000000  209.669998  107.589996  135.300003  ...
# 2023-01-31  247.190857  144.289993  213.000000  108.489998  134.729996  ...
# 2023-02-01  252.118515  145.429993  214.750000  109.389999  135.089996  ...
# 2023-02-02  263.938904  150.820007  209.339996  113.209999  136.389999  ...
# 2023-02-03  257.704529  154.500000  206.009995  110.709999  136.940002  ...
#
#                   Open                                        Volume           \
#                    DIS         IBM         KO        MSFT       AAPL       BA
# Date
# 2023-01-30  108.260002  134.320007  60.540001  244.509995   64015300  6066800
# 2023-01-31  107.580002  135.500000  60.980000  243.449997   65874500  5163000
# 2023-02-01  108.500000  134.490005  61.139999  248.000000   77663600  8462100
# 2023-02-02  110.669998  135.960007  60.799999  258.820007  118339000  6513400
# 2023-02-03  111.470001  136.350006  60.349998  259.540009  154357300  5400300
#
#
#                  DIS      IBM        KO      MSFT
# Date
# 2023-01-30   8548500  5375700  15632000  25867400
# 2023-01-31   8251700  7206400  14344400  26541100
# 2023-02-01   9975500  5428900  12535400  31259900
# 2023-02-02  13093200  6107800  16947200  39940400
# 2023-02-03  12472500  3755700  15404400  29077300
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3295 entries, 2010-01-04 to 2023-02-03
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3295 non-null   float64
#  1   (Adj Close, BA)    3295 non-null   float64
#  2   (Adj Close, DIS)   3295 non-null   float64
#  3   (Adj Close, IBM)   3295 non-null   float64
#  4   (Adj Close, KO)    3295 non-null   float64
#  5   (Adj Close, MSFT)  3295 non-null   float64
#  6   (Close, AAPL)      3295 non-null   float64
#  7   (Close, BA)        3295 non-null   float64
#  8   (Close, DIS)       3295 non-null   float64
#  9   (Close, IBM)       3295 non-null   float64
#  10  (Close, KO)        3295 non-null   float64
#  11  (Close, MSFT)      3295 non-null   float64
#  12  (High, AAPL)       3295 non-null   float64
#  13  (High, BA)         3295 non-null   float64
#  14  (High, DIS)        3295 non-null   float64
#  15  (High, IBM)        3295 non-null   float64
#  16  (High, KO)         3295 non-null   float64
#  17  (High, MSFT)       3295 non-null   float64
#  18  (Low, AAPL)        3295 non-null   float64
#  19  (Low, BA)          3295 non-null   float64
#  20  (Low, DIS)         3295 non-null   float64
#  21  (Low, IBM)         3295 non-null   float64
#  22  (Low, KO)          3295 non-null   float64
#  23  (Low, MSFT)        3295 non-null   float64
#  24  (Open, AAPL)       3295 non-null   float64
#  25  (Open, BA)         3295 non-null   float64
#  26  (Open, DIS)        3295 non-null   float64
#  27  (Open, IBM)        3295 non-null   float64
#  28  (Open, KO)         3295 non-null   float64
#  29  (Open, MSFT)       3295 non-null   float64
#  30  (Volume, AAPL)     3295 non-null   int64
#  31  (Volume, BA)       3295 non-null   int64
#  32  (Volume, DIS)      3295 non-null   int64
#  33  (Volume, IBM)      3295 non-null   int64
#  34  (Volume, KO)       3295 non-null   int64
#  35  (Volume, MSFT)     3295 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 952.5 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777554  27.933918  80.328041  18.936365  23.623899
# 2010-01-05  6.516527  45.211357  27.864241  79.357674  18.707300  23.631529
# 2010-01-06  6.412873  46.582802  27.716162  78.842171  18.700668  23.486509
# 2010-01-07  6.401017  48.468552  27.724874  78.569275  18.654179  23.242250
# 2010-01-08  6.443574  48.001011  27.768425  79.357674  18.308918  23.402550
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#            ('Close', 'AAPL'),       ('Close', 'BA'),      ('Close', 'DIS'),
#             ('Close', 'IBM'),       ('Close', 'KO'),     ('Close', 'MSFT'),
#             ('High', 'AAPL'),        ('High', 'BA'),       ('High', 'DIS'),
#              ('High', 'IBM'),        ('High', 'KO'),      ('High', 'MSFT'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#             ('Open', 'AAPL'),        ('Open', 'BA'),       ('Open', 'DIS'),
#              ('Open', 'IBM'),        ('Open', 'KO'),      ('Open', 'MSFT'),
#           ('Volume', 'AAPL'),      ('Volume', 'BA'),     ('Volume', 'DIS'),
#            ('Volume', 'IBM'),      ('Volume', 'KO'),    ('Volume', 'MSFT')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777554  27.933918  80.328041  18.936365  23.623899
# 2010-01-05  6.516527  45.211357  27.864241  79.357674  18.707300  23.631529
# 2010-01-06  6.412873  46.582802  27.716162  78.842171  18.700668  23.486509
# 2010-01-07  6.401017  48.468552  27.724874  78.569275  18.654179  23.242250
# 2010-01-08  6.443574  48.001011  27.768425  79.357674  18.308918  23.402550
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1)
# Out:
#                   AAPL                                                  \
#              Adj Close       Close        High         Low        Open
# Date
# 2010-01-04    6.505279    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.516527    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.412873    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.401017    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.443574    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2023-01-30  142.781998  143.000000  145.550003  142.850006  144.960007
# 2023-01-31  144.070023  144.289993  144.339996  142.279999  142.699997
# 2023-02-01  145.208282  145.429993  146.610001  141.320007  143.970001
# 2023-02-02  150.590088  150.820007  151.179993  148.169998  148.899994
# 2023-02-03  154.264465  154.500000  157.380005  147.830002  148.029999
#
#                                BA                                      ...  \
#                Volume   Adj Close       Close        High         Low  ...
# Date                                                                   ...
# 2010-01-04  493729600   43.777554   56.180000   56.389999   54.799999  ...
# 2010-01-05  601904800   45.211357   58.020000   58.279999   56.000000  ...
# 2010-01-06  552160000   46.582802   59.779999   59.990002   57.880001  ...
# 2010-01-07  477131200   48.468552   62.200001   62.310001   59.020000  ...
# 2010-01-08  447610800   48.001011   61.599998   61.779999   60.860001  ...
# ...               ...         ...         ...         ...         ...  ...
# 2023-01-30   64015300  209.669998  209.669998  211.360001  207.710007  ...
# 2023-01-31   65874500  213.000000  213.000000  213.110001  208.240005  ...
# 2023-02-01   77663600  214.750000  214.750000  218.970001  211.899994  ...
# 2023-02-02  118339000  209.339996  209.339996  215.289993  208.300003  ...
# 2023-02-03  154357300  206.009995  206.009995  210.750000  205.619995  ...
#
#                    KO                                        MSFT              \
#                  High        Low       Open    Volume   Adj Close       Close
# Date
# 2010-01-04  28.610001  28.450001  28.580000  13870400   23.623899   30.950001
# 2010-01-05  28.495001  28.070000  28.424999  23172400   23.631529   30.959999
# 2010-01-06  28.219999  27.990000  28.174999  19264600   23.486509   30.770000
# 2010-01-07  28.184999  27.875000  28.165001  13234600   23.242250   30.450001
# 2010-01-08  27.820000  27.375000  27.730000  28712400   23.402550   30.660000
# ...               ...        ...        ...       ...         ...         ...
# 2023-01-30  61.169998  60.459999  60.540001  15632000  242.103607  242.710007
# 2023-01-31  61.340000  60.509998  60.980000  14344400  247.190857  247.809998
# 2023-02-01  61.580002  60.619999  61.139999  12535400  252.118515  252.750000
# 2023-02-02  61.020000  59.910000  60.799999  16947200  263.938904  264.600006
# 2023-02-03  60.419998  59.230000  60.349998  15404400  257.704529  258.350006
#
#
#                   High         Low        Open    Volume
# Date
# 2010-01-04   31.100000   30.590000   30.620001  38409100
# 2010-01-05   31.100000   30.639999   30.850000  49749600
# 2010-01-06   31.080000   30.520000   30.879999  58182400
# 2010-01-07   30.700001   30.190001   30.629999  50559700
# 2010-01-08   30.879999   30.240000   30.280001  51197400
# ...                ...         ...         ...       ...
# 2023-01-30  245.600006  242.199997  244.509995  25867400
# 2023-01-31  247.949997  242.949997  243.449997  26541100
# 2023-02-01  255.179993  245.470001  248.000000  31259900
# 2023-02-02  264.690002  257.250000  258.820007  39940400
# 2023-02-03  264.200012  257.100006  259.540009  29077300
#
# [3295 rows x 36 columns]

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777554  27.933918  80.328041  18.936365  23.623899
# 2010-01-05  6.516527  45.211357  27.864241  79.357674  18.707300  23.631529
# 2010-01-06  6.412873  46.582802  27.716162  78.842171  18.700668  23.486509
# 2010-01-07  6.401017  48.468552  27.724874  78.569275  18.654179  23.242250
# 2010-01-08  6.443574  48.001011  27.768425  79.357674  18.308918  23.402550
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL          BA         DIS         IBM         KO
# Date
# 2023-01-30  142.781998  209.669998  107.589996  133.658249  60.178402
# 2023-01-31  144.070023  213.000000  108.489998  133.095169  60.853226
# 2023-02-01  145.208282  214.750000  109.389999  133.450790  60.863152
# 2023-02-02  150.590088  209.339996  113.209999  134.735031  59.821140
# 2023-02-03  154.264465  206.009995  110.709999  135.278351  59.374569
#
#                              Close                                      ...  \
#                   MSFT        AAPL          BA         DIS         IBM  ...
# Date                                                                    ...
# 2023-01-30  242.103607  143.000000  209.669998  107.589996  135.300003  ...
# 2023-01-31  247.190857  144.289993  213.000000  108.489998  134.729996  ...
# 2023-02-01  252.118515  145.429993  214.750000  109.389999  135.089996  ...
# 2023-02-02  263.938904  150.820007  209.339996  113.209999  136.389999  ...
# 2023-02-03  257.704529  154.500000  206.009995  110.709999  136.940002  ...
#
#                   Open                                        Volume           \
#                    DIS         IBM         KO        MSFT       AAPL       BA
# Date
# 2023-01-30  108.260002  134.320007  60.540001  244.509995   64015300  6066800
# 2023-01-31  107.580002  135.500000  60.980000  243.449997   65874500  5163000
# 2023-02-01  108.500000  134.490005  61.139999  248.000000   77663600  8462100
# 2023-02-02  110.669998  135.960007  60.799999  258.820007  118339000  6513400
# 2023-02-03  111.470001  136.350006  60.349998  259.540009  154357300  5400300
#
#
#                  DIS      IBM        KO      MSFT
# Date
# 2023-01-30   8548500  5375700  15632000  25867400
# 2023-01-31   8251700  7206400  14344400  26541100
# 2023-02-01   9975500  5428900  12535400  31259900
# 2023-02-02  13093200  6107800  16947200  39940400
# 2023-02-03  12472500  3755700  15404400  29077300
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3295 entries, 2010-01-04 to 2023-02-03
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3295 non-null   float64
#  1   (Adj Close, BA)    3295 non-null   float64
#  2   (Adj Close, DIS)   3295 non-null   float64
#  3   (Adj Close, IBM)   3295 non-null   float64
#  4   (Adj Close, KO)    3295 non-null   float64
#  5   (Adj Close, MSFT)  3295 non-null   float64
#  6   (Close, AAPL)      3295 non-null   float64
#  7   (Close, BA)        3295 non-null   float64
#  8   (Close, DIS)       3295 non-null   float64
#  9   (Close, IBM)       3295 non-null   float64
#  10  (Close, KO)        3295 non-null   float64
#  11  (Close, MSFT)      3295 non-null   float64
#  12  (High, AAPL)       3295 non-null   float64
#  13  (High, BA)         3295 non-null   float64
#  14  (High, DIS)        3295 non-null   float64
#  15  (High, IBM)        3295 non-null   float64
#  16  (High, KO)         3295 non-null   float64
#  17  (High, MSFT)       3295 non-null   float64
#  18  (Low, AAPL)        3295 non-null   float64
#  19  (Low, BA)          3295 non-null   float64
#  20  (Low, DIS)         3295 non-null   float64
#  21  (Low, IBM)         3295 non-null   float64
#  22  (Low, KO)          3295 non-null   float64
#  23  (Low, MSFT)        3295 non-null   float64
#  24  (Open, AAPL)       3295 non-null   float64
#  25  (Open, BA)         3295 non-null   float64
#  26  (Open, DIS)        3295 non-null   float64
#  27  (Open, IBM)        3295 non-null   float64
#  28  (Open, KO)         3295 non-null   float64
#  29  (Open, MSFT)       3295 non-null   float64
#  30  (Volume, AAPL)     3295 non-null   int64
#  31  (Volume, BA)       3295 non-null   int64
#  32  (Volume, DIS)      3295 non-null   int64
#  33  (Volume, IBM)      3295 non-null   int64
#  34  (Volume, KO)       3295 non-null   int64
#  35  (Volume, MSFT)     3295 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 952.5 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           BA          DIS          IBM           KO
# count  3295.000000  3295.000000  3295.000000  3295.000000  3295.000000
# mean     50.009003   161.713850    91.450797   111.972938    36.641256
# std      48.150237    98.552816    41.975830    14.300992    11.583176
# min       5.837760    43.777554    25.536148    74.226883    16.761835
# 25%      16.633737    73.301689    54.845570   104.663734    28.275954
# 50%      27.664808   129.500931    96.555702   112.453407    34.480309
# 75%      59.114677   219.345001   111.570129   123.031982    44.301880
# max     180.683868   430.299988   201.910004   148.742966    64.306442
#
#                           Close                                         ...  \
#               MSFT         AAPL           BA          DIS          IBM  ...
# count  3295.000000  3295.000000  3295.000000  3295.000000  3295.000000  ...
# mean     96.099158    51.923900   171.799311    94.955211   148.417052  ...
# std      89.555724    47.740532    96.251896    40.465380    23.940066  ...
# min      17.725113     6.858929    56.180000    29.000000    90.602295  ...
# 25%      26.050829    18.991428    86.915001    60.330000   129.804016  ...
# 50%      50.791969    30.000000   141.809998    99.879997   142.791580  ...
# 75%     135.929398    60.290001   219.345001   114.370003   166.840347  ...
# max     339.075592   182.009995   440.619995   201.910004   206.309753  ...
#
#               Open                                               Volume  \
#                DIS          IBM           KO         MSFT          AAPL
# count  3295.000000  3295.000000  3295.000000  3295.000000  3.295000e+03
# mean     94.984762   148.370446    43.982900   101.060200  2.550264e+08
# std      40.531380    23.922074     8.926376    88.699552  2.222906e+08
# min      28.730000    90.439774    25.110001    23.090000  3.519590e+07
# 25%      60.180000   129.775337    38.570000    31.900000  1.016992e+08
# 50%     100.169998   143.030594    42.779999    56.150002  1.659340e+08
# 75%     114.480000   166.754303    49.115000   140.609993  3.432986e+08
# max     200.190002   205.908218    67.000000   344.619995  1.880998e+09
#
#
#                  BA           DIS           IBM            KO          MSFT
# count  3.295000e+03  3.295000e+03  3.295000e+03  3.295000e+03  3.295000e+03
# mean   7.413442e+06  9.777176e+06  5.037409e+06  1.514784e+07  3.797883e+07
# std    8.893625e+06  6.167670e+06  2.774654e+06  6.707810e+06  2.141586e+07
# min    7.889000e+05  2.165700e+06  1.247878e+06  2.996300e+06  7.425600e+06
# 25%    3.414250e+06  6.416650e+06  3.438778e+06  1.084765e+07  2.390595e+07
# 50%    4.725000e+06  8.185900e+06  4.345189e+06  1.365470e+07  3.222990e+07
# 75%    7.487400e+06  1.100360e+07  5.658598e+06  1.760550e+07  4.675360e+07
# max    1.032128e+08  8.741070e+07  3.981442e+07  9.896750e+07  3.193179e+08
#
# [8 rows x 36 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2023-01-30    1870.940625
# 2023-01-31    1887.818253
# 2023-02-01    1902.733436
# 2023-02-02    1973.253698
# 2023-02-03    2021.400885
# Name: AAPL, Length: 3295, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# BA       56.180000
# DIS      32.070000
# IBM     126.625237
# KO       28.520000
# MSFT     30.950001
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                    AAPL          BA         DIS         IBM          KO  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893  103.275187   99.750546   98.792000   98.790318
# 2010-01-06    98.579511  106.407972   99.220455   98.150247   98.755261
# 2010-01-07    98.397266  110.715558   99.251638   97.810499   98.509814
# 2010-01-08    99.051443  109.647558   99.407544   98.792000   96.686537
# ...                 ...         ...         ...         ...         ...
# 2023-01-30  1870.940625  373.211102  335.484869  106.850741  212.622715
# 2023-01-31  1887.818253  379.138481  338.291234  106.400588  215.007008
# 2023-02-01  1902.733436  382.253469  341.097600  106.684892  215.042079
# 2023-02-02  1973.253698  372.623701  353.009043  107.711546  211.360441
# 2023-02-03  2021.400885  366.696321  345.213596  108.145901  209.782612
#
#                   MSFT
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.032305
# 2010-01-06   99.418416
# 2010-01-07   98.384491
# 2010-01-08   99.063002
# ...                ...
# 2023-01-30  784.200325
# 2023-01-31  800.678486
# 2023-02-01  816.639721
# 2023-02-02  854.927301
# 2023-02-03  834.733440
#
# [3295 rows x 6 columns]

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## The shift() method

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.shift(periods = 1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2023-01-30  145.929993
# 2023-01-31  143.000000
# 2023-02-01  144.289993
# 2023-02-02  145.429993
# 2023-02-03  150.820007
#
# [3295 rows x 1 columns]

# %%
aapl.shift(periods = -1)
# Out:
#                   AAPL
# Date
# 2010-01-04    7.656429
# 2010-01-05    7.534643
# 2010-01-06    7.520714
# 2010-01-07    7.570714
# 2010-01-08    7.503929
# ...                ...
# 2023-01-30  144.289993
# 2023-01-31  145.429993
# 2023-02-01  150.820007
# 2023-02-02  154.500000
# 2023-02-03         NaN
#
# [3295 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1
# Date
# 2010-01-04  7.643214       NaN
# 2010-01-05  7.656429  7.643214
# 2010-01-06  7.534643  7.656429
# 2010-01-07  7.520714  7.534643
# 2010-01-08  7.570714  7.520714

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2023-01-30   -2.929993
# 2023-01-31    1.289993
# 2023-02-01    1.139999
# 2023-02-02    5.390015
# 2023-02-03    3.679993
# Length: 3295, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff
# Date
# 2010-01-04  7.643214       NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000

# %%
aapl.AAPL.div(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    1.001729
# 2010-01-06    0.984094
# 2010-01-07    0.998151
# 2010-01-08    1.006648
#                 ...
# 2023-01-30    0.979922
# 2023-01-31    1.009021
# 2023-02-01    1.007901
# 2023-02-02    1.037063
# 2023-02-03    1.024400
# Length: 3295, dtype: float64

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.172893
# 2010-01-06   -1.590632
# 2010-01-07   -0.184871
# 2010-01-08    0.664833
#                 ...
# 2023-01-30   -2.007807
# 2023-01-31    0.902093
# 2023-02-01    0.790075
# 2023-02-02    3.706261
# 2023-02-03    2.439990
# Length: 3295, dtype: float64

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833

# %% [markdown]
# ## The methods diff() and pct_change()

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06   -0.108571
# 2010-01-07   -0.135715
# 2010-01-08    0.036071
#                 ...
# 2023-01-30   -0.960007
# 2023-01-31   -1.639999
# 2023-02-01    2.429993
# 2023-02-02    6.530014
# 2023-02-03    9.070007
# Name: AAPL, Length: 3295, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000
# 2010-01-11  7.503929  7.570714 -0.066785   -0.882147 -0.066785
# 2010-01-12  7.418571  7.503929 -0.085358   -1.137513 -0.085358
# 2010-01-13  7.523214  7.418571  0.104643    1.410553  0.104643
# 2010-01-14  7.479643  7.523214 -0.043571   -0.579154 -0.043571
# 2010-01-15  7.354643  7.479643 -0.125000   -1.671203 -0.125000

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN          NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215     0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786    -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929    -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000     0.664833

# %%
aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30   -12.227255
# 2023-01-31    11.052106
# 2023-02-28     7.076032
# Freq: BM, Name: AAPL, Length: 158, dtype: float64

# %% [markdown]
# ## Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2023-01-30 -0.020078
# 2023-01-31  0.009021
# 2023-02-01  0.007901
# 2023-02-02  0.037063
# 2023-02-03  0.024400
#
# [3294 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3294 entries, 2010-01-05 to 2023-02-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3294 non-null   float64
# dtypes: float64(1)
# memory usage: 51.5 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.001077
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000328
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.018097
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.018097
# dtype: float64

# %% [markdown]
# 연단위로 변경

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    0.271389
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    0.082532
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.287284
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.287284
# dtype: float64

# %% [markdown]
# ## Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
close.pct_change().dropna()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720
# ...              ...       ...       ...       ...       ...       ...
# 2023-01-30 -0.020078 -0.007103 -0.017802  0.006771  0.002480 -0.021962
# 2023-01-31  0.009021  0.015882  0.008365 -0.004213  0.011214  0.021013
# 2023-02-01  0.007901  0.008216  0.008296  0.002672  0.000163  0.019935
# 2023-02-02  0.037063 -0.025192  0.034921  0.009623 -0.017121  0.046884
# 2023-02-03  0.024400 -0.015907 -0.022083  0.004033 -0.007465 -0.023621
#
# [3294 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.describe()
# Out:
#               AAPL           BA          DIS          IBM           KO  \
# count  3294.000000  3294.000000  3294.000000  3294.000000  3294.000000
# mean      0.001077     0.000659     0.000511     0.000126     0.000287
# std       0.018097     0.022967     0.016459     0.014248     0.011093
# min      -0.128647    -0.238484    -0.131632    -0.128507    -0.096725
# 25%      -0.007620    -0.009198    -0.006761    -0.006366    -0.004806
# 50%       0.000892     0.000618     0.000450     0.000340     0.000482
# 75%       0.010660     0.010313     0.008117     0.007013     0.005888
# max       0.119808     0.243186     0.144123     0.113010     0.064796
#
#               MSFT
# count  3294.000000
# mean      0.000779
# std       0.016438
# min      -0.147390
# 25%      -0.007240
# 50%       0.000562
# 75%       0.009119
# max       0.142169

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#           mean       std
# AAPL  0.001077  0.018097
# BA    0.000659  0.022967
# DIS   0.000511  0.016459
# IBM   0.000126  0.014248
# KO    0.000287  0.011093
# MSFT  0.000779  0.016438

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001077  0.018097
# BA    0.000659  0.022967
# DIS   0.000511  0.016459
# IBM   0.000126  0.014248
# KO    0.000287  0.011093
# MSFT  0.000779  0.016438

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.271389  0.287284
# BA    0.165976  0.364585
# DIS   0.128895  0.261285
# IBM   0.031712  0.226180
# KO    0.072266  0.176103
# MSFT  0.196429  0.260939

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ## Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.cov()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  0.000328  0.000166  0.000126  0.000107  0.000071  0.000177
# BA    0.000166  0.000527  0.000200  0.000150  0.000109  0.000155
# DIS   0.000126  0.000200  0.000271  0.000105  0.000084  0.000132
# IBM   0.000107  0.000150  0.000105  0.000203  0.000077  0.000113
# KO    0.000071  0.000109  0.000084  0.000077  0.000123  0.000077
# MSFT  0.000177  0.000155  0.000132  0.000113  0.000077  0.000270

# %%
ret.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  1.000000  0.399192  0.423525  0.413425  0.351196  0.594345
# BA    0.399192  1.000000  0.529714  0.458994  0.429115  0.410099
# DIS   0.423525  0.529714  1.000000  0.448215  0.457666  0.486536
# IBM   0.413425  0.458994  0.448215  1.000000  0.485573  0.481482
# KO    0.351196  0.429115  0.457666  0.485573  1.000000  0.423856
# MSFT  0.594345  0.410099  0.486536  0.481482  0.423856  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()

# %% [markdown]
# ## Simple Returns vs. Log Returns

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(index = [2016, 2017, 2018], data = [100, 50, 95], columns = ["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_returns = df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100 * 1.2 * 1.2
# Out:
# 144.0

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
np.log(df / df.shift(1))
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns = np.log(df / df.shift(1)).dropna()

# %%
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100 * np.exp(2 * log_returns.mean())
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ## Importing Financial Data from Excel

# %%
import pandas as pd

# %%
pd.read_excel("SP500.xls").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12107 entries, 0 to 12106
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       12107 non-null  datetime64[ns]
#  1   Open       12107 non-null  float64
#  2   High       12107 non-null  float64
#  3   Low        12107 non-null  float64
#  4   Close      12107 non-null  float64
#  5   Adj Close  12107 non-null  float64
#  6   Volume     12107 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 662.2 KB

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date")
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1970-12-31    92.269997    92.790001    91.360001    92.150002    92.150002
# 1971-01-04    92.150002    92.190002    90.639999    91.150002    91.150002
# 1971-01-05    91.150002    92.279999    90.690002    91.800003    91.800003
# 1971-01-06    91.800003    93.000000    91.500000    92.349998    92.349998
# 1971-01-07    92.349998    93.260002    91.750000    92.379997    92.379997
# ...                 ...          ...          ...          ...          ...
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990  2485.739990
#
#                 Volume
# Date
# 1970-12-31    13390000
# 1971-01-04    10010000
# 1971-01-05    12600000
# 1971-01-06    16960000
# 1971-01-07    16460000
# ...                ...
# 2018-12-21  -980924592
# 2018-12-24 -1681037296
# 2018-12-26   -60977296
# 2018-12-27  -198357296
# 2018-12-28  -592347296
#
# [12107 rows x 6 columns]

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols = "A, C:E")
# Out:
#                    High          Low        Close
# Date
# 1970-12-31    92.790001    91.360001    92.150002
# 1971-01-04    92.190002    90.639999    91.150002
# 1971-01-05    92.279999    90.690002    91.800003
# 1971-01-06    93.000000    91.500000    92.349998
# 1971-01-07    93.260002    91.750000    92.379997
# ...                 ...          ...          ...
# 2018-12-21  2504.409912  2408.550049  2416.620117
# 2018-12-24  2410.340088  2351.100098  2351.100098
# 2018-12-26  2467.760010  2346.580078  2467.699951
# 2018-12-27  2489.100098  2397.939941  2488.830078
# 2018-12-28  2520.270020  2472.889893  2485.739990
#
# [12107 rows x 3 columns]

# %%
pd.read_excel("SP500.xls", sheet_name= "Sales")
# Out:
#   Unnamed: 0      City  Sales
# 0       Mike  New York     25
# 1        Jim    Boston     43
# 2     Steven    London     76
# 3        Joe    Madrid     12
# 4        Tom     Paris     89

# %%
pd.read_excel("SP500.xls", sheet_name= 0)
# Out:
#             Date         Open         High          Low        Close  \
# 0     1970-12-31    92.269997    92.790001    91.360001    92.150002
# 1     1971-01-04    92.150002    92.190002    90.639999    91.150002
# 2     1971-01-05    91.150002    92.279999    90.690002    91.800003
# 3     1971-01-06    91.800003    93.000000    91.500000    92.349998
# 4     1971-01-07    92.349998    93.260002    91.750000    92.379997
# ...          ...          ...          ...          ...          ...
# 12102 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 12103 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 12104 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 12105 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 12106 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990
#
#          Adj Close      Volume
# 0        92.150002    13390000
# 1        91.150002    10010000
# 2        91.800003    12600000
# 3        92.349998    16960000
# 4        92.379997    16460000
# ...            ...         ...
# 12102  2416.620117  -980924592
# 12103  2351.100098 -1681037296
# 12104  2467.699951   -60977296
# 12105  2488.830078  -198357296
# 12106  2485.739990  -592347296
#
# [12107 rows x 7 columns]

# %%
SP500 = pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols= "A:E")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12107 entries, 1970-12-31 to 2018-12-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    12107 non-null  float64
#  1   High    12107 non-null  float64
#  2   Low     12107 non-null  float64
#  3   Close   12107 non-null  float64
# dtypes: float64(4)
# memory usage: 472.9 KB

# %%
SP500.to_csv("SP500.csv")

# %%
SP500.to_excel("SP500_red.xls")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_29516/124282479.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   SP500.to_excel("SP500_red.xls")

# %% [markdown]
# ## Simple Moving Averages (SMA) with rolling()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates = ["Date"], index_col = "Date")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12107 entries, 1970-12-31 to 2018-12-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    12107 non-null  float64
#  1   High    12107 non-null  float64
#  2   Low     12107 non-null  float64
#  3   Close   12107 non-null  float64
# dtypes: float64(4)
# memory usage: 472.9 KB

# %%
SP500 = SP500.Close.to_frame()

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500.plot(figsize = (12,8), fontsize= 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.rolling(window = 10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
type(SP500.rolling(window = 10))
# Out:
# pandas.core.window.rolling.Rolling

# %%
SP500.head(15)
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024
# 2009-01-08  909.729980
# 2009-01-09  890.349976
# 2009-01-12  870.260010
# 2009-01-13  871.789978
# 2009-01-14  842.619995
# 2009-01-15  843.739990
# 2009-01-16  850.119995
# 2009-01-20  805.219971
# 2009-01-21  840.239990
# 2009-01-22  827.500000

# %% [markdown]
# 단순이동평균

# %%
SP500.rolling(window = 10).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %%
SP500.rolling(window = 10).median()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2573.054931
# 2018-12-24  2546.049926
# 2018-12-26  2526.449951
# 2018-12-27  2497.895019
# 2018-12-28  2487.285034
#
# [2516 rows x 1 columns]

# %%
SP500.rolling(window = 10, min_periods=5).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07   920.770007
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %% [markdown]
# ## Momentum Trading Strategies with SMAs

# %%
SP500.head()
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024

# %%
SP500.tail()
# Out:
#                   Close
# Date
# 2018-12-21  2416.620117
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990

# %%
SP500["SMA50"] = SP500.rolling(window = 50, min_periods=50).mean()

# %%
SP500
# Out:
#                   Close        SMA50
# Date
# 2008-12-31   903.250000          NaN
# 2009-01-02   931.799988          NaN
# 2009-01-05   927.450012          NaN
# 2009-01-06   934.700012          NaN
# 2009-01-07   906.650024          NaN
# ...                 ...          ...
# 2018-12-21  2416.620117  2692.420195
# 2018-12-24  2351.100098  2684.874795
# 2018-12-26  2467.699951  2678.886196
# 2018-12-27  2488.830078  2673.646997
# 2018-12-28  2485.739990  2667.163398
#
# [2516 rows x 2 columns]

# %%
SP500.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500["SMA200"] = SP500.Close.rolling(window = 200).mean()

# %%
SP500.tail()
# Out:
#                   Close        SMA50      SMA200
# Date
# 2018-12-21  2416.620117  2692.420195  2753.65980
# 2018-12-24  2351.100098  2684.874795  2751.48245
# 2018-12-26  2467.699951  2678.886196  2749.90585
# 2018-12-27  2488.830078  2673.646997  2748.52345
# 2018-12-28  2485.739990  2667.163398  2747.20475

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2008-12-31 to 2018-12-28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2516 non-null   float64
#  1   SMA50   2467 non-null   float64
#  2   SMA200  2317 non-null   float64
# dtypes: float64(3)
# memory usage: 78.6 KB

# %%
SP500.plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ## Exponentially-weighted Moving Averages (EWMA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates= ["Date"], index_col= "Date", usecols= ["Date", "Close"])

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.Close.rolling(window = 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2565.915991
# 2018-12-24    2537.254004
# 2018-12-26    2520.345996
# 2018-12-27    2504.121997
# 2018-12-28    2487.641992
# Name: Close, Length: 2516, dtype: float64

# %%
SP500.Close.ewm(span = 10, min_periods= 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2547.124619
# 2018-12-24    2511.483797
# 2018-12-26    2503.523098
# 2018-12-27    2500.851640
# 2018-12-28    2498.104067
# Name: Close, Length: 2516, dtype: float64

# %%
SP500["SMA"] = SP500.Close.rolling(window = 100).mean()
SP500["EMA"] = SP500.Close.ewm(span = 100, min_periods= 100).mean()

# %%
SP500
# Out:
#                   Close          SMA          EMA
# Date
# 2008-12-31   903.250000          NaN          NaN
# 2009-01-02   931.799988          NaN          NaN
# 2009-01-05   927.450012          NaN          NaN
# 2009-01-06   934.700012          NaN          NaN
# 2009-01-07   906.650024          NaN          NaN
# ...                 ...          ...          ...
# 2018-12-21  2416.620117  2785.905496  2732.088580
# 2018-12-24  2351.100098  2781.282896  2724.544253
# 2018-12-26  2467.699951  2777.687695  2719.458228
# 2018-12-27  2488.830078  2774.172495  2714.891334
# 2018-12-28  2485.739990  2770.525896  2710.353683
#
# [2516 rows x 3 columns]

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize =15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ### Merging Time Series

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0]).Close

# %%
stocks.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
aapl = stocks.loc["2010-01-01" : "2014-12-31", "AAPL"].to_frame()
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
ba = stocks.loc["2012-01-01" : "2016-12-31", "BA"].to_frame()
ba.head()
# Out:
#                    BA
# Date
# 2012-01-03  74.220001
# 2012-01-04  74.330002
# 2012-01-05  73.529999
# 2012-01-06  73.980003
# 2012-01-09  74.529999

# %%
aapl["BA"] = ba.BA

# %%
aapl.head()
# Out:
#                 AAPL  BA
# Date
# 2010-01-04  7.643214 NaN
# 2010-01-05  7.656429 NaN
# 2010-01-06  7.534643 NaN
# 2010-01-07  7.520714 NaN
# 2010-01-08  7.570714 NaN

# %%
aapl.tail()
# Out:
#                  AAPL          BA
# Date
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996

# %%
aapl.dropna()
# Out:
#                  AAPL          BA
# Date
# 2012-01-03  14.686786   74.220001
# 2012-01-04  14.765714   74.330002
# 2012-01-05  14.929643   73.529999
# 2012-01-06  15.085714   73.980003
# 2012-01-09  15.061786   74.529999
# ...               ...         ...
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996
#
# [754 rows x 2 columns]

# %%
ba.reindex(aapl.index).dropna()
# Out:
#                     BA
# Date
# 2012-01-03   74.220001
# 2012-01-04   74.330002
# 2012-01-05   73.529999
# 2012-01-06   73.980003
# 2012-01-09   74.529999
# ...                ...
# 2014-12-24  131.240005
# 2014-12-26  131.630005
# 2014-12-29  132.289993
# 2014-12-30  131.830002
# 2014-12-31  129.979996
#
# [754 rows x 1 columns]

# %%
dis = stocks.loc["2010-01-01" : "2016-12-31", "DIS"].resample("W-Fri").last().to_frame()
dis.head()
# Out:
#                   DIS
# Date
# 2010-01-08  31.879999
# 2010-01-15  30.600000
# 2010-01-22  29.980000
# 2010-01-29  29.549999
# 2010-02-05  29.540001

# %%
aapl.head()
# Out:
#                 AAPL  BA
# Date
# 2010-01-04  7.643214 NaN
# 2010-01-05  7.656429 NaN
# 2010-01-06  7.534643 NaN
# 2010-01-07  7.520714 NaN
# 2010-01-08  7.570714 NaN

# %%
aapl["DIS"] = dis.DIS

# %%
aapl.head(10)
# Out:
#                 AAPL  BA        DIS
# Date
# 2010-01-04  7.643214 NaN        NaN
# 2010-01-05  7.656429 NaN        NaN
# 2010-01-06  7.534643 NaN        NaN
# 2010-01-07  7.520714 NaN        NaN
# 2010-01-08  7.570714 NaN  31.879999
# 2010-01-11  7.503929 NaN        NaN
# 2010-01-12  7.418571 NaN        NaN
# 2010-01-13  7.523214 NaN        NaN
# 2010-01-14  7.479643 NaN        NaN
# 2010-01-15  7.354643 NaN  30.600000

# %%
dis.reindex(aapl.index)
# Out:
#                   DIS
# Date
# 2010-01-04        NaN
# 2010-01-05        NaN
# 2010-01-06        NaN
# 2010-01-07        NaN
# 2010-01-08  31.879999
# ...               ...
# 2014-12-24        NaN
# 2014-12-26  95.029999
# 2014-12-29        NaN
# 2014-12-30        NaN
# 2014-12-31        NaN
#
# [1258 rows x 1 columns]

# %%
dis["AAPL"] = aapl.AAPL

# %%
dis.head(10)
# Out:
#                   DIS      AAPL
# Date
# 2010-01-08  31.879999  7.570714
# 2010-01-15  30.600000  7.354643
# 2010-01-22  29.980000  7.062500
# 2010-01-29  29.549999  6.859286
# 2010-02-05  29.540001  6.980714
# 2010-02-12  30.070000  7.156429
# 2010-02-19  31.230000  7.202500
# 2010-02-26  31.240000  7.307857
# 2010-03-05  33.220001  7.819643
# 2010-03-12  33.689999  8.092857
